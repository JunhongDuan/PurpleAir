# %%
# data downloaded from: https://www.epa.gov/outdoor-air-quality-data/download-daily-data

# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
pm25_2020 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2020.csv')
pm25_2021 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2021.csv')
pm25_2022 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2022.csv')

pm10_2020 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2020.csv')
pm10_2021 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2021.csv')
pm10_2022 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2022.csv')

no2_2020 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2020.csv')
no2_2021 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2021.csv')
no2_2022 = pd.read_csv('../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2022.csv')
pm25_2020.head()
# Out:
#        Date Source   Site ID  POC  Daily Mean PM2.5 Concentration     Units  \
# 0  1/1/2020    AQS  60370002   21                             8.4  ug/m3 LC
# 1  1/1/2020    AQS  60370016    3                             9.6  ug/m3 LC
# 2  1/1/2020    AQS  60371103    1                            17.4  ug/m3 LC
# 3  1/1/2020    AQS  60371103    9                            18.6  ug/m3 LC
# 4  1/1/2020    AQS  60371201    1                            15.4  ug/m3 LC
#
#    Daily AQI Value                Local Site Name  Daily Obs Count  \
# 0               47                          Azusa                1
# 1               52                       Glendora                1
# 2               66  Los Angeles-North Main Street                1
# 3               69  Los Angeles-North Main Street                1
# 4               63                         Reseda                1
#
#    Percent Complete  ...  Method Code  \
# 0               100  ...          143
# ...

# %%
# merge all year data and cut data within 2020-12-1 to 2022-12-1
paths = [
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2020.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2021.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm25_2022.csv"
]
df_list = [pd.read_csv(p) for p in paths]
df_pm25 = pd.concat(df_list, ignore_index=True)

# filter date
df_pm25['Date'] = pd.to_datetime(df_pm25['Date'])
start = pd.Timestamp("2020-12-01")
end   = pd.Timestamp("2022-12-01")
mask = (df_pm25['Date'] >= start) & (df_pm25['Date'] <= end)
df_pm25_filtered = df_pm25.loc[mask].copy()

# %%
# covert into shapefile
df_pm25_filtered = gpd.GeoDataFrame(
    df_pm25_filtered,
    geometry=gpd.points_from_xy(df_pm25_filtered['Site Longitude'], df_pm25_filtered['Site Latitude']),
    crs="EPSG:4326"
)
df_pm25_filtered['Date'] = df_pm25_filtered['Date'].dt.date.astype(str)
df_pm25_filtered.to_file('../Data/Output/epa_pm25_history.shp')
# Out:
# C:\Users\jduan\AppData\Local\Temp\ipykernel_3720\3246903204.py:8: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   df_pm25_filtered.to_file('../Data/Output/epa_pm25_history.shp')

# %%
# pm10
# merge all year data and cut data within 2020-12-1 to 2022-12-1
paths = [
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2020.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2021.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_pm10_2022.csv"
]
df_list = [pd.read_csv(p) for p in paths]
df_pm10 = pd.concat(df_list, ignore_index=True)

# filter date
df_pm10['Date'] = pd.to_datetime(df_pm10['Date'])
start = pd.Timestamp("2020-12-01")
end   = pd.Timestamp("2022-12-01")
mask = (df_pm10['Date'] >= start) & (df_pm10['Date'] <= end)
df_pm10_filtered = df_pm10.loc[mask].copy()

# covert into shapefile
df_pm10_filtered = gpd.GeoDataFrame(
    df_pm10_filtered,
    geometry=gpd.points_from_xy(df_pm10_filtered['Site Longitude'], df_pm10_filtered['Site Latitude']),
    crs="EPSG:4326"
)
df_pm10_filtered['Date'] = df_pm10_filtered['Date'].dt.date.astype(str)
df_pm10_filtered.to_file('../Data/Output/epa_pm10_history.shp')
# Out:
# C:\Users\jduan\AppData\Local\Temp\ipykernel_3720\3840933294.py:25: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   df_pm10_filtered.to_file('../Data/Output/epa_pm10_history.shp')

# %%
# no2
# merge all year data and cut data within 2020-12-1 to 2022-12-1
paths = [
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2020.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2021.csv",
    "../Data/Raw data/EPA air quality data/ad_viz_plotval_data_no2_2022.csv"
]
df_list = [pd.read_csv(p) for p in paths]
df_no2 = pd.concat(df_list, ignore_index=True)

# filter date
df_no2['Date'] = pd.to_datetime(df_no2['Date'])
start = pd.Timestamp("2020-12-01")
end   = pd.Timestamp("2022-12-01")
mask = (df_no2['Date'] >= start) & (df_no2['Date'] <= end)
df_no2_filtered = df_no2.loc[mask].copy()

# covert into shapefile
df_no2_filtered = gpd.GeoDataFrame(
    df_no2_filtered,
    geometry=gpd.points_from_xy(df_no2_filtered['Site Longitude'], df_no2_filtered['Site Latitude']),
    crs="EPSG:4326"
)
df_no2_filtered['Date'] = df_no2_filtered['Date'].dt.date.astype(str)
df_no2_filtered.to_file('../Data/Output/epa_no2_history.shp')
# Out:
# C:\Users\jduan\AppData\Local\Temp\ipykernel_3720\3520274818.py:25: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   df_no2_filtered.to_file('../Data/Output/epa_no2_history.shp')

# %%
df_pm25_filtered.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'Units', 'Daily AQI Value', 'Local Site Name', 'Daily Obs Count',
#        'Percent Complete', 'AQS Parameter Code', 'AQS Parameter Description',
#        'Method Code', 'Method Description', 'CBSA Code', 'CBSA Name',
#        'State FIPS Code', 'State', 'County FIPS Code', 'County',
#        'Site Latitude', 'Site Longitude', 'geometry'],
#       dtype='object')
